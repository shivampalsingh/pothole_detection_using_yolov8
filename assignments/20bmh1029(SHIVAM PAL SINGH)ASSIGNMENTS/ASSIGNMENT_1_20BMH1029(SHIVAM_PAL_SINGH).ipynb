# %% [markdown]
# Assignment 1 (20BMH1029 SHIVAM PAL SINGH)

# %%
import pandas as pd
import numpy as np

# %%
s1 = pd.Series(np.random.rand(4))
s2 = pd.Series(np.random.rand(4))
s3 = pd.Series(np.random.rand(4))
s4 = pd.Series(np.random.rand(4))
print(s1,s2,s3,s4)
# Out:
# 0    0.029580
# 1    0.195417
# 2    0.384198
# 3    0.922017
# dtype: float64 0    0.944321
# 1    0.290608
# 2    0.854225
# 3    0.406404
# dtype: float64 0    0.113246
# 1    0.798040
# 2    0.718091
# 3    0.302360
# dtype: float64 0    0.497047
# 1    0.465923
# 2    0.983712
# 3    0.768730
# dtype: float64

# %% [markdown]
# Task 1

# %%
df = pd.DataFrame([s1,s2,s3,s4])
df
# Out:
#           0         1         2         3
# 0  0.029580  0.195417  0.384198  0.922017
# 1  0.944321  0.290608  0.854225  0.406404
# 2  0.113246  0.798040  0.718091  0.302360
# 3  0.497047  0.465923  0.983712  0.768730

# %% [markdown]
# Task-2

# %%
df.columns = ['Random Value 1','Random Value 2','Random Value 3','Random Value 4']
df
# Out:
#    Random Value 1  Random Value 2  Random Value 3  Random Value 4
# 0        0.029580        0.195417        0.384198        0.922017
# 1        0.944321        0.290608        0.854225        0.406404
# 2        0.113246        0.798040        0.718091        0.302360
# 3        0.497047        0.465923        0.983712        0.768730

# %% [markdown]
# Task 3

# %%
df.describe()
# Out:
#        Random Value 1  Random Value 2  Random Value 3  Random Value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.396048        0.437497        0.735056        0.599878
# std          0.418362        0.265191        0.257824        0.293390
# min          0.029580        0.195417        0.384198        0.302360
# 25%          0.092329        0.266810        0.634618        0.380393
# 50%          0.305146        0.378266        0.786158        0.587567
# 75%          0.608865        0.548952        0.886597        0.807052
# max          0.944321        0.798040        0.983712        0.922017

# %% [markdown]
# Task 4

# %%
df.isnull()
# Out:
#    Random Value 1  Random Value 2  Random Value 3  Random Value 4
# 0           False           False           False           False
# 1           False           False           False           False
# 2           False           False           False           False
# 3           False           False           False           False

# %%
df['Random Value 1'].dtype
# Out:
# dtype('float64')

# %%
df['Random Value 2'].dtype
# Out:
# dtype('float64')

# %%
df['Random Value 3'].dtype
# Out:
# dtype('float64')

# %%
df['Random Value 4'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# Task 5

# %%
df.loc[0:3,'Random Value 2':'Random Value 3']
# Out:
#    Random Value 2  Random Value 3
# 0        0.195417        0.384198
# 1        0.290608        0.854225
# 2        0.798040        0.718091
# 3        0.465923        0.983712

# %%
df.iloc[0:,1:3]
# Out:
#    Random Value 2  Random Value 3
# 0        0.195417        0.384198
# 1        0.290608        0.854225
# 2        0.798040        0.718091
# 3        0.465923        0.983712
